# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# 한글 나오게 해주는 라이브러리
import koreanize_matplotlib

# %%
plt.title('선 그래프')
plt.plot([1,3,5,7,9],[1,9,35,67,70])
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
import matplotlib.font_manager as fm
# 한글 폰트를 찾아서 plt.rc에 인자로 넣어주면 된다.
# fm.findSystemFonts(fontpaths=None, fontext='ttf')
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
plt.title('선 그래프')
plt.plot([1,3,5,7,9],[1,9,35,67,70])
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
x = list(range(100))
def fun(x):
    return x*2
plt.title('선 그래프')
plt.plot(fun(x))
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22184\115392395.py in <module>
#       3     return x*2
#       4 plt.title('선 그래프')
# ----> 5 plt.plot(x,fun(x))
#       6 plt.xlabel('X축')
#       7 plt.ylabel('Y축')
#
# c:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
# -> 2769         **({"data": data} if data is not None else {}), **kwargs)
#    2770
#    2771
#
# c:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# c:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# c:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (200,)
